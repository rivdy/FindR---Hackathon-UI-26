# %% [markdown]
# # PhormulAI ? Document extraction
# Extract authorized CoA and regulatory documents while retaining source evidence.
#
# Scaffold only: no trained model, experimental results, or performance claims.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
if not (PROJECT_ROOT / "app" / "main.py").is_file():
    raise RuntimeError("Run from racikai-backend or its notebooks directory.")
DATA_DIR = PROJECT_ROOT / "data"

# %% [markdown]
# ## Next steps
# Connect verified input data and implement the workflow before running experiments.
